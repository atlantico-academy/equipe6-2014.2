# %%
import pandas as pd

df = pd.read_csv("../raw/Churn_Modelling.csv")

dicionario = pd.DataFrame([
    {
        "Variavel":"RowNumber",
        "Descrição":"O número sequencial atribuído a cada linha no conjunto de dados.",
        "Tipo":"Quantitativo",
        "Subtipo":"Discreta"
    },{
        "Variavel":"CustomerId",
        "Descrição":"Identificador único de cada cliente",
        "Tipo":"Quantitativo",
        "Subtipo":"Discreta"
    },{
        "Variavel":"Surname",
        "Descrição":"Indica o sobrenome do cliente.",
        "Tipo":"Qualitativo",
        "Subtipo":"Nominal"
    },{
        "Variavel":"CreditScore",
        "Descrição":"Indica a pontuação de crédito do cliente.",
        "Tipo":"Quantitativo",
        "Subtipo":"Discreta"
    },{
        "Variavel":"Geography",
        "Descrição":"Localização geográfica do cliente (país ou região)",
        "Tipo":"Qualitativo",
        "Subtipo":"Nominal"
    },{
        "Variavel":"Gender",
        "Descrição":"Gênero do cliente",
        "Tipo":"Qualitativo",
        "Subtipo":"Nominal"
    },{
        "Variavel":"Age",
        "Descrição":"Idade do cliente",
        "Tipo":"Quantitativo",
        "Subtipo":"Discreta"
    },{
        "Variavel":"Tenure",
        "Descrição":"Indica número de anos que o cliente está no banco.",
        "Tipo":"Quantitativo",
        "Subtipo":"Discreta"
    },{
        "Variavel":"Balance",
        "Descrição":"Indica o saldo da conta do cliente",
        "Tipo":"Quantitativo",
        "Subtipo":"Contínua"
    },{
        "Variavel":"NumOfProducts",
        "Descrição":"Indica o número de produtos bancários que o cliente possui",
        "Tipo":"Quantitativo",
        "Subtipo":"Discreta"
    },{
        "Variavel":"HasCrCard",
        "Descrição":"Indica se o cliente tem cartão de crédito (sim ou nao)",
        "Tipo":"Qualitativo",
        "Subtipo":"Nominal"
    },{
        "Variavel":"IsActiveMember",
        "Descrição":"Indica se o cliente é um membro ativo (sim ou nao)",
        "Tipo":"Qualitativo",
        "Subtipo":"Nominal"
    },{
        "Variavel":"EstimatedSalary",
        "Descrição":"Indica o salário estimado do cliente",
        "Tipo":"Quantitativo",
        "Subtipo":"Contínua"
    },{
        "Variavel":"Exited",
        "Descrição":"Indica se o cliente saiu ou não do banco (sim ou nao)",
        "Tipo":"Qualitativo",
        "Subtipo":"Nominal"
    }

])

dicionario.to_csv("dicionario.csv", index = False)
